# %% [markdown]
# <a href="https://colab.research.google.com/github/shahankit82/ml-assessment-Ankit-Shah/blob/main/Part_a/q2_unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q2 Unsupervised Learning - Customer Segmentation (K-Means + PCA)
#
# Beginner-friendly notebook

# %% [markdown]
# ## 1. Data Preparation

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv('https://raw.githubusercontent.com/shahankit82/ml-assessment-Ankit-Shah/refs/heads/main/Data/q2_customers.csv')

df.head()
# Out:
#    age  annual_spend  visits_per_month  basket_size  days_since_last_visit  \
# 0   30         43075                 9         2080                     45
# 1   19         14496                11          454                      8
# 2   43         57632                 6         2144                     16
# 3   30         15629                10          801                      0
# 4   19         14901                16          396                     17
#
#    num_categories_purchased
# 0                         6
# 1                         3
# 2                         4
# 3                         2
# 4                         1

# %%
# Scale features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

scaled_df = pd.DataFrame(scaled_data, columns=df.columns)

scaled_df.head()
# Out:
#         age  annual_spend  visits_per_month  basket_size  \
# 0 -0.725219     -0.176150          0.110166    -0.265011
# 1 -1.488460     -1.046826          0.486157    -0.980466
# 2  0.176795      0.267337         -0.453822    -0.236851
# 3 -0.725219     -1.012309          0.298161    -0.827783
# 4 -1.488460     -1.034488          1.426136    -1.005986
#
#    days_since_last_visit  num_categories_purchased
# 0              -0.089951                  0.550952
# 1              -0.835176                 -0.680685
# 2              -0.674046                 -0.270139
# 3              -0.996306                 -1.091230
# 4              -0.653905                 -1.501776

# %% [markdown]
# Scaling is important because K-Means uses distance. Features with larger values can dominate the clustering if not scaled.

# %% [markdown]
# ## 2. Choosing K - Elbow Method

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# Choose K where the curve starts to bend (elbow point).

# %% [markdown]
# ## 3. K-Means Clustering

# %%
# Choose K (example: 3, update based on your plot)
k = 3

kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(scaled_df)

df['cluster'] = clusters

df.head()
# Out:
#    age  annual_spend  visits_per_month  basket_size  days_since_last_visit  \
# 0   30         43075                 9         2080                     45
# 1   19         14496                11          454                      8
# 2   43         57632                 6         2144                     16
# 3   30         15629                10          801                      0
# 4   19         14901                16          396                     17
#
#    num_categories_purchased  cluster
# 0                         6        2
# 1                         3        0
# 2                         4        2
# 3                         2        0
# 4                         1        0

# %%
# Centroids
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=scaled_df.columns)
centroids
# Out:
#         age  annual_spend  visits_per_month  basket_size  \
# 0 -1.094595     -1.036122          1.114284    -0.934278
# 1  1.132214      1.235574         -1.106680     1.253260
# 2 -0.004449     -0.168055         -0.041370    -0.290670
#
#    days_since_last_visit  num_categories_purchased
# 0              -0.813494                 -1.045346
# 1               1.125725                  1.172991
# 2              -0.287579                 -0.095968

# %% [markdown]
# Interpret clusters based on centroid values (high/low features).

# %% [markdown]
# ## 4. PCA Dimensionality Reduction

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_df)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.83560354 0.05568764]

# %%
# Loadings
loadings = pd.DataFrame(pca.components_, columns=scaled_df.columns, index=['PC1','PC2'])
loadings
# Out:
#           age  annual_spend  visits_per_month  basket_size  \
# PC1  0.411569       0.42154         -0.410399     0.412012
# PC2 -0.259432      -0.03327          0.208318    -0.195402
#
#      days_since_last_visit  num_categories_purchased
# PC1               0.378582                  0.414017
# PC2               0.911194                 -0.140479

# %% [markdown]
# PC1 and PC2 show combinations of features that explain most variance.

# %% [markdown]
# ## 5. Cluster Visualisation

# %%
plt.scatter(pca_data[:,0], pca_data[:,1], c=df['cluster'])
plt.title("Clusters visualised with PCA")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
